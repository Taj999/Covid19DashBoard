# %%
from requests import get
import pandas as df

def get_data(url):
    response = get(endpoint, timeout=10)
    
    if response.status_code >= 400:
        raise RuntimeError(f'Request failed: { response.text }')
        
    return response.json()
    

endpoint = (
    'https://api.coronavirus.data.gov.uk/v1/data?'
    'filters=areaType=nation&'
    'structure={"date":"date","areaName":"areaName","areaCode":"areaCode","newCasesByPublishDate":"newCasesByPublishDate","cumCasesByPublishDate":"cumCasesByPublishDate","newDeathsByDeathDate":"newDeathsByDeathDate","cumDeathsByDeathDate":"cumDeathsByDeathDate"}'
)

data = get_data(endpoint)
print(data['data'])
# Out:
# [{'date': '2020-11-22', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 16668, 'cumCasesByPublishDate': 1301559, 'newDeathsByDeathDate': None, 'cumDeathsByDeathDate': None}, {'date': '2020-11-21', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 17615, 'cumCasesByPublishDate': 1284891, 'newDeathsByDeathDate': 40, 'cumDeathsByDeathDate': 58221}, {'date': '2020-11-20', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 17845, 'cumCasesByPublishDate': 1267276, 'newDeathsByDeathDate': 231, 'cumDeathsByDeathDate': 58181}, {'date': '2020-11-19', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 20291, 'cumCasesByPublishDate': 1249431, 'newDeathsByDeathDate': 338, 'cumDeathsByDeathDate': 57950}, {'date': '2020-11-18', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 17189, 'cumCasesByPublishDate': 1229140, 'newDeathsByDeathDate': 412, 'cumDeathsByDeathDate': 57612}, {'date': '2020-11-17', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 17549, 'cumCasesByPublishDate': 1211951, 'newDeathsByDeathDate': 386, 'cumDeathsByDeathDate': 57200}, {'date': '2020-11-16', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 19423, 'cumCasesByPublishDate': 1194402, 'newDeathsByDeathDate': 364, 'cumDeathsByDeathDate': 56814}, {'date': '2020-11-15', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 21998, 'cumCasesByPublishDate': 1174979, 'newDeathsByDeathDate': 379, 'cumDeathsByDeathDate': 56450}, {'date': '2020-11-14', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 24298, 'cumCasesByPublishDate': 1152981, 'newDeathsByDeathDate': 378, 'cumDeathsByDeathDate': 56071}, {'date': '2020-11-13', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 24540, 'cumCasesByPublishDate': 1128683, 'newDeathsByDeathDate': 374, 'cumDeathsByDeathDate': 55693}, {'date': '2020-11-12', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 30843, 'cumCasesByPublishDate': 1104143, 'newDeathsByDeathDate': 383, 'cumDeathsByDeathDate': 55319}, {'date': '2020-11-11', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 19970, 'cumCasesByPublishDate': 1073300, 'newDeathsByDeathDate': 364, 'cumDeathsByDeathDate': 54936}, {'date': '2020-11-10', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 18622, 'cumCasesByPublishDate': 1053330, 'newDeathsByDeathDate': 363, 'cumDeathsByDeathDate': 54572}, {'date': '2020-11-09', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 19036, 'cumCasesByPublishDate': 1034708, 'newDeathsByDeathDate': 461, 'cumDeathsByDeathDate': 54209}, {'date': '2020-11-08', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 18293, 'cumCasesByPublishDate': 1015672, 'newDeathsByDeathDate': 387, 'cumDeathsByDeathDate': 53748}, {'date': '2020-11-07', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 21875, 'cumCasesByPublishDate': 997379, 'newDeathsByDeathDate': 377, 'cumDeathsByDeathDate': 53361}, {'date': '2020-11-06', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 20268, 'cumCasesByPublishDate': 975504, 'newDeathsByDeathDate': 367, 'cumDeathsByDeathDate': 52984}, {'date': '2020-11-05', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 21137, 'cumCasesByPublishDate': 955236, 'newDeathsByDeathDate': 368, 'cumDeathsByDeathDate': 52617}, {'date': '2020-11-04', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 21863, 'cumCasesByPublishDate': 934099, 'newDeathsByDeathDate': 316, 'cumDeathsByDeathDate': 52249}, {'date': '2020-11-03', 'areaName': 'England', 'areaCode': 'E92000001', 'newCasesByPublishDate': 17330, 'cumCasesByPublishDate': 912236, 'newDeathsByDeathDate': 336, 'cumDeathsByDeathDate': 51933}, {'date': '2020-11-02', 'areaName': 'England', ...

# %%
# df.DataFrame.from_records(data)
# train = df.DataFrame.from_dict(data['data'], orient='index')
from pandas.io.json import json_normalize
dataframe=json_normalize(data['data'])
# Out:
# c:\users\haddi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.

# %%
import matplotlib.pyplot as plt
dataframe['date']=dataframe['date'].astype('datetime64')
dataframe['date'].count()
# Out:
# 1300

# %%
plt.bar(dataframe['date'],dataframe['newCasesByPublishDate'])
# Out:
# <BarContainer object of 1300 artists>

# %%
plt.bar(dataframe['date'],dataframe['cumDeathsByDeathDate'])
# Out:
# <BarContainer object of 1300 artists>

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
from datetime import datetime
from IPython.display import display
start_date = datetime(2018, 4, 24)
end_date = datetime(2018, 5, 24)

dates = df.date_range(start_date, end_date, freq='D')

options = [(date.strftime(' %d %b %Y '), date) for date in dates]
index = (0, len(options)-1)

selection_range_slider = widgets.SelectionRangeSlider(
    options=options,
    index=index,
    description='Dates',
    orientation='horizontal',
    layout={'width': '500px'}
)

display(selection_range_slider)
# Out:
# SelectionRangeSlider(description='Dates', index=(0, 30), layout=Layout(width='500px'), options=((' 24 Apr 2018…

# %%
from ipywidgets import widgets, interactive
v = interactive(by_q, quarter=(['q1y2015', 'q2y2015', 'q3y2015', 'q4y2015']), days=(1, 180))
display(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8153f4a75768> in <module>
#       1 from ipywidgets import widgets, interactive
# ----> 2 v = interactive(by_q, quarter=(['q1y2015', 'q2y2015', 'q3y2015', 'q4y2015']), days=(1, 180))
#       3 display(v)
#
# NameError: name 'by_q' is not defined
